# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup 

from sqlalchemy import create_engine


def getProxyIp():
    engine = create_engine('mysql+pymysql://root:root@localhost:3306/proxyip')

    iplist = engine.execute('select ip from ipdata where isok = 1').fetchall()
    return iplist

# %%
# 创建数据库
import pymysql

db = pymysql.connect("localhost","root","root","bilidata" )

cursor = db.cursor()

# 个人信息库
sql = """CREATE TABLE userinfo (
        id int not null,
        name varchar(20),
        sex int(1),
        birthday varchar(20),
        article int,
        fans int,
        followers int,
        level int
        )"""

# 番剧关注库 uid用户 aid 番剧编号
sql2 = """create table animefollow(
        uid int,
        aid int
        )"""
# 用户关注库 uid用户， ufid关注者编号
sql3 = """create table userfollow(
        uid int,
        ufid int
        )"""

# 番剧信息
# sql4 = """create table animeinfo(
#         aid int,
#         anmae varchar(50)
#         )"""
cursor.execute(sql)
cursor.execute(sql2)
cursor.execute(sql3)
db.close()

# %%
# 官方api https://api.bilibili.com/x/space/acc/info?mid=3003362&jsonp=jsonp
# api链接1 https://api.kaaass.net/biliapi/user/space?id=123
# api链接2 https://api.bilibili.com/x/relation/stat?vmid=3572779
# 获取数据部分，对userinfo库 和 animefollow库进行 录入

# 数据录入时间 2019-09-12
from sqlalchemy import create_engine
import time
import requests

# def getUserInfo(api, ):
    
engine = create_engine('mysql+pymysql://root:root@localhost:3306/bilidata')

for i in range(20129,40000):
    if i % 200 == 0:
        print('已完成200人录入')
        time.sleep(10)
    try:
        r = requests.get("https://api.kaaass.net/biliapi/user/space?id="+str(i))
        card = r.json()['data']['card']
        if card['sex'] == '男':
            sex = 0
        elif card['sex'] == '女':
            sex = 1
        else : sex = 2
        engine.execute("insert into userinfo (id, name, sex, birthday, article, fans, followers, level) values ('"+card['mid']+"', '"+card['name']+"', '"+str(sex)+"', '"+card['birthday']+"', '"+str(card['article'])+"', '"+str(card['fans'])+"', '"+str(card['attention'])+"', '"+str(card['level_info']['current_level'])+"')")
        for j in r.json()['data']['season']['item']:
            engine.execute("insert into animefollow (uid, aid) values ('"+card['mid']+"', '"+j['param']+"')") 
    except:
        print(i,'用户录入失败')



# 20000 - 20129
# 1- 1255

# item - param 为番剧编号。 count 52数量 为全部番剧
# 根据关注番剧 进行番剧推荐。
# coin_archive - param 近期投币视频 count数量
# Out:
# D:\Anaconda3_5\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'name' at row 1")
#   result = self._query(query)
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 21363 用户录入失败
# 已完成200人录入
# 21539 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 22773 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 23812 用户录入失败
# 23859 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 24222 用户录入失败
# 24236 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 25581 用户录入失败
# 已完成200人录入
# 25611 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 26087 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 27559 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 28109 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 28953 用户录入失败
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 已完成200人录入
# 30443 用户录入失败
# 已完成200人录入
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:root@localhost:3306/bilidata')

for i in range(10000,20000):
    r = requests.get("https://api.kaaass.net/biliapi/user/space?id="+str(i))
    try:
        card = r.json()['data']['card']
        if card['sex'] == '男':
            sex = 0
        elif card['sex'] == '女':
            sex = 1
        else : sex = 2
        engine.execute("insert into userinfo (id, name, sex, birthday, article, fans, followers, level) values ('"+card['mid']+"', '"+card['name']+"', '"+str(sex)+"', '"+card['birthday']+"', '"+str(card['article'])+"', '"+str(card['fans'])+"', '"+str(card['attention'])+"', '"+str(card['level_info']['current_level'])+"')")
        for j in r.json()['data']['season']['item']:
            engine.execute("insert into animefollow (uid, aid) values ('"+card['mid']+"', '"+j['param']+"')") 

        if i % 200 == 0:
            print('已完成200人录入')
    except:
        print(i,'用户录入失败')

# %%
chrome_options = Options()
iplen = len(iplist)

# 遍历的第n个uuid， 代理ip使用 对iplen取模的代理，
# num = 1

failList = []

for num in range(1,10):
    
    # 设置代理ip
    chrome_options.add_argument("--proxy-server=http://" + iplist[num%iplen][0])
    # 不开启浏览器
    chrome_options.add_argument('--headless')
    # 禁用gpu
    chrome_options.add_argument('--disable-gpu')
    # 模仿浏览器user-agent
    chrome_options.add_argument('user-agent="Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36"')

    driver = webdriver.Chrome(chrome_options=chrome_options)

    url="https://space.bilibili.com/"

    # 读取页面开始try，若有问题直接跳过。
    try:
        driver.get(url+str(num))

        html = driver.page_source

        soup = BeautifulSoup(html, "lxml")

        name = soup.find('span',id='h-name').text
        follows = ''.join(soup.find('a',class_='n-gz').attrs['title'].split(','))
        fans = ''.join(soup.find('a',class_='n-fs').attrs['title'].split(','))
        views = ''.join(soup.find('div',class_='n-bf').attrs['title'].split(','))
        engine2 = create_engine('mysql+pymysql://root:root@localhost:3306/bilidata')
        engine2.execute("insert into userinfo (uuid, name, follows, fans, views) values ('"+str(num)+"','"+name+"','"+follows+"','"+fans+"','"+views+"')")
        print("成功将第",num,"用户信息读入数据库")
    except Exception as e:
        print("第",num,"用户失败")
        failList.append(num)
        print(e)

    driver.close() # 回收资源
# Out:
# D:\Anaconda3_5\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: use options instead of chrome_options
# 第 1 用户失败
# 'NoneType' object has no attribute 'text'
# 第 2 用户失败
# 'NoneType' object has no attribute 'text'
# 第 3 用户失败
# 'NoneType' object has no attribute 'text'
# 第 4 用户失败
# 'NoneType' object has no attribute 'text'
# 第 5 用户失败
# 'NoneType' object has no attribute 'text'
# 第 6 用户失败
# 'NoneType' object has no attribute 'text'
# 第 7 用户失败
# 'NoneType' object has no attribute 'text'
# Exception ignored in: <bound method Service.__del__ of <selenium.webdriver.chrome.service.Service object at 0x0000025206214FD0>>
# Traceback (most recent call last):
#   File "D:\Anaconda3_5\lib\site-packages\selenium\webdriver\common\service.py", line 176, in __del__
#     self.stop()
#   File "D:\Anaconda3_5\lib\site-packages\selenium\webdriver\common\service.py", line 151, in stop
#     self.send_remote_shutdown_command()
# ...

# %%
import requests
from lxml import etree
import random
import time

iplen = len(iplist)

# 遍历的第n个uuid， 代理ip使用 对iplen取模的代理，
# num = 1

# failList = []

# user_agent_list = ["Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36",
#                     "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36",
#                     "Mozilla/5.0 (Windows NT 10.0; ) Gecko/20100101 Firefox/61.0",
#                     "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36",
#                     "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.62 Safari/537.36",
#                     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36",
#                     "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0)",
#                     "Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10.5; en-US; rv:1.9.2.15) Gecko/20110303 Firefox/3.6.15",
#                     ]
                

for num in range(1,10):
    
    url="https://space.bilibili.com/"
    
#     proxies={'https': '127.0.0.1:8765' }
    headers = {}
    headers['User-Agent'] = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36"
#     headers['Sec-Fetch-Mode'] = "navigate"
#     headers['Sec-Fetch-User'] =  "?1"
#     headers['Connection'] = "keep-alive"
#     headers['Cache-Control'] = "max-age=0"
#     headers['Upgrade-Insecure-Requests'] = "1"
#     headers['Accept'] = "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3"
#     headers['Sec-Fetch-Site'] = "none"
#     headers['Accept-Encoding'] = "gzip, deflate, br"
#     headers['Accept-Language'] = "zh-CN,zh;q=0.9"
    
#     Cookie = {}
#     Cookie['buvid3']="97D2927B-1741-4660-865C-256A5BDD09F7110238infoc"
#     Cookie['CURRENT_FNVAL']="16"
#     Cookie['LIVE_BUVID']="AUTO5715566707713372"
#     Cookie['stardustvideo']="1"
#     Cookie['sid']="alzfbnnj"
#     Cookie['rpdid']="|(u|u)u~)YR|0J'ullYY)l)Jm"
#     Cookie['fts']="1556687799"
#     Cookie['_uuid']="C1909AA6-64C2-356F-CB19-ACBA9684B21B62286infoc"
#     Cookie['UM_distinctid']="16a72018619c1-05483c18d425ab-7a1437-144000-16a7201861a483"
#     Cookie['im_notify_type_3003362']="0"
#     Cookie['arrange']="matrix"
#     Cookie['_uuid']="04B3EF50-8B30-A04A-6DF2-8971139E1A1960624infoc"
#     Cookie['im_local_unread_3003362']="0"
#     Cookie['im_seqno_3003362']="31476"
#     Cookie['stardustpgcv']="0606"
#     Cookie['CURRENT_QUALITY']="112"
#     Cookie['Hm_lvt_8a6e55dbd2870f0f5bc9194cddf32a02']="1567175767,1567588565,1567746295,1567774051"
#     Cookie['Hm_lpvt_8a6e55dbd2870f0f5bc9194cddf32a02']="1567774051"
#     Cookie['DedeUserID']="3003362"
#     Cookie['DedeUserID__ckMd5']="388eb4c5ec74de9e"
#     Cookie['SESSDATA']="d307e4a9%2C1570714344%2C5938c391"
#     Cookie['bili_jct']="ca3559fcb81a1f2f1c6070543f899ae3"
#     Cookie['bp_t_offset_3003362']="297570989428182030"
#     Cookie['CNZZDATA2724999']="cnzz_eid%3D1824959455-1556689913-https%253A%252F%252Fwww.bilibili.com%252F%26ntime%3D1568127371"


    try:
        res = requests.get(url+str(num),  headers=headers, timeout=5, verify=False)
#         res = requests.get(url+str(num), headers=headers, cookies=Cookie, timeout=2)
        print(res.status_code)
#         print(res.text)
        soup = BeautifulSoup(res.text, "lxml")

        name = soup.find('span', id='h-name').text
        follows = ''.join(soup.find('a',class_='n-gz').attrs['title'].split(','))
        fans = ''.join(soup.find('a',class_='n-fs').attrs['title'].split(','))
        views = ''.join(soup.find('div',class_='n-bf').attrs['title'].split(','))
        engine2 = create_engine('mysql+pymysql://root:root@localhost:3306/bilidata')
        engine2.execute("insert into userinfo (uuid, name, follows, fans, views) values ('"+str(num)+"','"+name+"','"+follows+"','"+fans+"','"+views+"')")
        print("成功将第",num,"用户信息读入数据库")
    except Exception as e:
        print("第",num,"用户失败")
        failList.append(num)
        print(e)
    time.sleep(5)
# Out:
# D:\Anaconda3_5\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# D:\Anaconda3_5\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 200
# 第 1 用户失败
# 'NoneType' object has no attribute 'text'
# 200
# 第 2 用户失败
# 'NoneType' object has no attribute 'text'
# D:\Anaconda3_5\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...
